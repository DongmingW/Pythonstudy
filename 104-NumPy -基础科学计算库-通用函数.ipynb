# %% [markdown]
# #### NumPy 包含大量的各种数学运算的函数：
# * 标准的三角函数：sin()、cos()、tan()、arcsin，arccos，和 arctan 。
# * 舍入函数：numpy.around() 函数返回指定数字的四舍五入值、numpy.floor() 返回数字的下舍整数、numpy.ceil() 返回数字的上入整数。
# * 加减乘除算术运算: add()，subtract()，multiply() 和 divide()。
# * numpy.power() 函数将第一个输入数组中的元素作为底数，计算它与第二个输入数组中相应元素的幂。
# * numpy.mod() 计算输入数组中相应元素的相除后的余数。 函数 numpy.remainder() 也产生相同的结果。
#
# #### NumPy 提供了很多统计函数：
# * 查找最小元素，最大元素：numpy.amin() 和 numpy.amax()
#
# * 计算数组中元素最大值与最小值的差（最大值 - 最小值）：numpy.ptp()
#
# * 计算数组 a 中元素的中位数（中值）：numpy.median() 函数
#
# * 百分位数：numpy.percentile()，百分位数是统计中使用的度量，表示小于这个值的观察值的百分比。
#
# * 数组中元素的算术平均值：numpy.mean() 函数，如果提供了轴，则沿其计算。
#
# * 加权平均值：numpy.average() 函数根据在另一个数组中给出的各自的权重计算数组中元素的加权平均值。
#
# * 方差：numpy.var，方差（样本方差）是每个样本值与全体样本值的平均数之差的平方值的平均数： mean((x - x.mean())** 2)。
#
# * 标准差：numpy.std，标准差是一组数据平均值分散程度的一种度量。标准差是方差的算术平方根：sqrt(mean((x - x.mean())**2))
#
# #### NumPy 排序、索引函数：
# * 排序函数：numpy.sort()、numpy.lexsort()等
# * 索引相关函数：numpy.argmax() 、 numpy.argmin()、numpy.nonzero()、umpy.argsort()、numpy.where()
#
# #### NumPy 位运算函数
# * bitwise_and	对数组元素执行位与操作
# * bitwise_or	对数组元素执行位或操作
# * invert	按位取反
# * left_shift	向左移动二进制表示的位
# * right_shift	向右移动二进制表示的位
#
# #### 字符串函数
# * add()	对两个数组的逐个字符串元素进行连接
# * multiply()	返回按元素多重连接后的字符串
# * center()	居中字符串
# * capitalize()	将字符串第一个字母转换为大写
# * title()	将字符串的每个单词的第一个字母转换为大写
# * lower()	数组元素转换为小写
# * upper()	数组元素转换为大写
# * split()	指定分隔符对字符串进行分割，并返回数组列表
# * splitlines()	返回元素中的行列表，以换行符分割
# * strip()	移除元素开头或者结尾处的特定字符
# * join()	通过指定分隔符来连接数组中的元素
# * replace()	使用新字符串替换字符串中的所有子字符串
# * decode()	数组元素依次调用str.decode
# * encode()	数组元素依次调用str.encode

# %% [markdown]
# 1.  元素级别的函数
#
# 　　元素级别的函数也就是函数对数组中的每一个元素进行运算。
# 一元函数（接受一个数组参数）:
# ![image.png](attachment:image.png)

# %% [markdown]
# 二元函数：
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 数组级别的函数
#
# 　　数组级别的函数一般是一些统计函数，像聚合类的函数求和（sum）,求平均（mean）等。
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.布尔数组的函数
#
# any() 函数： 只有有一个为True，返回结果为True
#
# all() 函数: 　　所有值都为True的时候，结果才为True

# %% [markdown]
# 4. 集合函数
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. 线性代数函数
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. 随机数函数
# ![image.png](attachment:image.png)
