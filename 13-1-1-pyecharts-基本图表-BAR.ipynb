# %% [markdown]
# ## Bar（柱状图/条形图）
# ####    柱状/条形图，通过柱形的高度/条形的宽度来表现数据的大小。
#
# ## Bar.add() 方法
#
# ####   add(name, x_axis, y_axis,    is_stack=False,    bar_category_gap='20%', **kwargs)
# ######   name -> str   图例名称
# ######   x_axis -> list  x 坐标轴数据
# ######   y_axis -> list  y 坐标轴数据
# ######   is_stack -> bool  数据堆叠，同个类目轴上系列配置相同的 stack 值可以堆叠放置
# ######   bar_category_gap -> int/str  类目轴的柱状距离，当设置为 0 时柱状是紧挨着（直方图类型），默认为 '20%'

# %% [markdown]
# ## is_stack 实现数据堆叠

# %%
from pyecharts import Bar

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图数据堆叠示例")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)
#bar.render('mychart1.html')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5104eca45b7c488296db5016e03bc11b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5104eca45b7c488296db5016e03bc11b = echarts.init(document.getElementById('5104eca45b7c488296db5016e03bc11b'), 'light', {renderer: 'canvas'});
#
# var option_5104eca45b7c488296db5016e03bc11b = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ## 使用标记点和标记线

# %%
from pyecharts import Bar
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]

bar = Bar("标记线和标记点示例")
bar.add("商家A", attr, v1, mark_point=["average"])
bar.add("商家B", attr, v2, mark_line=["min", "max"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="647187c0eacd4a7a8f5faae3bbe8478e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_647187c0eacd4a7a8f5faae3bbe8478e = echarts.init(document.getElementById('647187c0eacd4a7a8f5faae3bbe8478e'), 'light', {renderer: 'canvas'});
#
# var option_647187c0eacd4a7a8f5faae3bbe8478e = {
#     "title": [
#         {
#             "text": "\u6807\u8bb0\u7ebf\u548c\u6807\u8bb0\u70b9\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ## is_convert 交换 XY 轴

# %%
from pyecharts import Bar
attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, v2, is_convert=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0168169caacd4ea089a934f2e4ffd252" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0168169caacd4ea089a934f2e4ffd252 = echarts.init(document.getElementById('0168169caacd4ea089a934f2e4ffd252'), 'light', {renderer: 'canvas'});
#
# var option_0168169caacd4ea089a934f2e4ffd252 = {
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## dataZoom 效果

# %% [markdown]
# #### dataZoom 组件 用于区域缩放，从而能自由关注细节的数据信息，或者概览数据整体，或者去除离群点的影响。
# #### (Line、Bar、Scatter、EffectScatter、Kline)

# %% [markdown]
# ## 默认的 dataZoom 控制条
#
# #### is_datazoom_show -> bool    默认 -> False  是否使用区域缩放组件。
#
# #### datazoom_type -> str  默认 -> 'slider'   区域缩放组件类型，有'slider', 'inside', 'both'可选。
#
# #### datazoom_range -> list  默认 -> [50, 100]  区域缩放的范围。
#
# ####  datazoom_orient -> str  默认 -> 'horizontal'（效果显示在 x 轴）datazoom 组件在直角坐标系中的方向。如若设置为 'vertical' 的话效果显示在 y 轴。
#
# #### datazoom_xaxis_index -> int/list  datazoom 组件控制的 x 轴索引  默认控制第一个 x 轴，如没特殊需求无须显示指定。单个为 int 类型而控制多个为 list 类型，如 [0, 1] 表示控制第一个和第二个 x 轴。
#
# #### datazoom_yaxis_index -> int/list datazoom 组件控制的 y 轴索引,  默认控制第一个 y 轴，如没特殊需求无须显示指定。单个为 int 类型而控制多个为 list 类型，如 [0, 1] 表示控制第一个和第二个 x 轴。
#
# ## 额外的 dataZoom 控制条
# #### is_datazoom_extra_show -> bool  默认 -> False  是否使用额外区域缩放组件。
#
# #### datazoom_extra_type -> str   默认 -> 'slider'  额外区域缩放组件类型，有'slider', 'inside', 'both'可选
#
# #### datazoom_extra_range -> list  默认 -> [50, 100]  额外区域缩放的范围。
#
# datazoom_extra_orient -> str
# 额外 datazoom 组件在直角坐标系中的方向，默认为 'vertical'，效果显示在 y 轴。如若设置为 'horizontal' 的话效果显示在 x 轴。
#
# datazoom_extra_xaxis_index -> int/list
# 额外 datazoom 组件控制的 x 轴索引 默认控制第一个 x 轴，如没特殊需求无须显示指定。单个为 int 类型而控制多个为 list 类型，如 [0, 1] 表示控制第一个和第二个 x 轴。
#
# datazoom_extra_yaxis_index -> int/list
# 额外 datazoom 组件控制的 y 轴索引 默认控制第一个 y 轴，如没特殊需求无须显示指定。单个为 int 类型而控制多个为 list 类型，如 [0, 1] 表示控制第一个和第二个 x 轴。

# %% [markdown]
# ## dataZoom 效果，'slider' 类型

# %%
from pyecharts import Bar
import random

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - slider 示例")
bar.add("", attr, v1,  is_label_show=True,is_datazoom_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="544ddc5d25bd4b8ba85d50a435e8b88a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_544ddc5d25bd4b8ba85d50a435e8b88a = echarts.init(document.getElementById('544ddc5d25bd4b8ba85d50a435e8b88a'), 'light', {renderer: 'canvas'});
#
# var option_544ddc5d25bd4b8ba85d50a435e8b88a = {
#     "title": [
#         {
#             "text": "Bar - datazoom - slider \u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## dataZoom 效果，'inside' 类型

# %%
attr = ["{}天".format(i+1) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - inside 示例")
bar.add(
    "",
    attr,
    v1,
    is_datazoom_show=True,
    datazoom_type="inside",
    datazoom_range=[1, 25],
)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="53ae09c749c64bbdaac7148709399530" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_53ae09c749c64bbdaac7148709399530 = echarts.init(document.getElementById('53ae09c749c64bbdaac7148709399530'), 'light', {renderer: 'canvas'});
#
# var option_53ae09c749c64bbdaac7148709399530 = {
#     "title": [
#         {
#             "text": "Bar - datazoom - inside \u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## dataZoom 效果，'both' 类型

# %%
attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - inside 示例")
bar.add(
    "",
    attr,
    v1,
    is_datazoom_show=True,
    datazoom_type="both",
    datazoom_range=[10, 25],
)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c99e7ada459e47e2992a71603094a898" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c99e7ada459e47e2992a71603094a898 = echarts.init(document.getElementById('c99e7ada459e47e2992a71603094a898'), 'light', {renderer: 'canvas'});
#
# var option_c99e7ada459e47e2992a71603094a898 = {
#     "title": [
#         {
#             "text": "Bar - datazoom - inside \u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## 多 dataZoom 效果，效果同时支持 X、Y 轴

# %%
days = ["{}天".format(i+1) for i in range(30)]
days_v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - xaxis/yaxis 示例")
bar.add(
    "",
    days,
    days_v1,
    # 默认为 X 轴，横向
    is_datazoom_show=True,
    datazoom_type="slider",
    datazoom_range=[1, 25],
    # 新增额外的 dataZoom 控制条，纵向
    is_datazoom_extra_show=True,
    datazoom_extra_type="slider",
    datazoom_extra_range=[1, 25],
    is_toolbox_show=False,
)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2312955c9fd04170a5b03ddaa98d38c8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2312955c9fd04170a5b03ddaa98d38c8 = echarts.init(document.getElementById('2312955c9fd04170a5b03ddaa98d38c8'), 'light', {renderer: 'canvas'});
#
# var option_2312955c9fd04170a5b03ddaa98d38c8 = {
#     "title": [
#         {
#             "text": "Bar - datazoom - xaxis/yaxis \u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "series_id": 462328,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
# ...

# %% [markdown]
# ## 当 x 轴或者 y 轴的标签因为过于密集而导致全部显示出来会重叠的话，可采用使标签旋转的方法

# %%
attr = ["{}天".format(i) for i in range(20)]
v1 = [random.randint(1, 20) for _ in range(20)]
bar = Bar("坐标轴标签旋转示例")
bar.add("", attr, v1, xaxis_interval=0, xaxis_rotate=30, yaxis_rotate=30)
bar

# %% [markdown]
# ## 瀑布图示例

# %%
from pyecharts import Bar

attr = ["{}月".format(i) for i in range(1, 8)]
v1 = [0, 100, 200, 300, 400, 220, 250]
v2 = [1000, 800, 600, 500, 450, 400, 300]
bar = Bar("瀑布图示例")
# 利用第一个 add() 图例的颜色为透明，即 'rgba(0,0,0,0)'，并且设置 is_stack 标志为 True
bar.add("", attr, v1, label_color=['rgba(0,0,0,0)'], is_stack=True)
bar.add("月份", attr, v2, is_label_show=True, is_stack=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c892486bdc3846e1ac2a9408bb608e96" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c892486bdc3846e1ac2a9408bb608e96 = echarts.init(document.getElementById('c892486bdc3846e1ac2a9408bb608e96'), 'light', {renderer: 'canvas'});
#
# var option_c892486bdc3846e1ac2a9408bb608e96 = {
#     "title": [
#         {
#             "text": "\u7011\u5e03\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## 直方图示例

# %%
from pyecharts import Bar

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("直方图示例")
bar.add("", attr * 2, v1 + v2, bar_category_gap=0)
bar

# %% [markdown]
# ## 某地的降水量和蒸发量柱状图

# %%
from pyecharts import Bar

attr = ["{}月".format(i) for i in range(1, 13)]
v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
bar = Bar("柱状图示例")
bar.add("蒸发量", attr, v1, mark_line=["average"], mark_point=["max", "min"])
bar.add("降水量", attr, v2, mark_line=["average"], mark_point=["max", "min"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bfd44fed723d4d688d19d25f0a158f3a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bfd44fed723d4d688d19d25f0a158f3a = echarts.init(document.getElementById('bfd44fed723d4d688d19d25f0a158f3a'), 'light', {renderer: 'canvas'});
#
# var option_bfd44fed723d4d688d19d25f0a158f3a = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %% [markdown]
# ## 额外的文本标签

# %%
from pyecharts import Bar
CLOTHES = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
clothes_v1 = [5, 20, 36, 10, 75, 90]
clothes_v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图", extra_html_text_label=["bar_extra_html_text_label", "color:red"])
bar.add("商家A", CLOTHES, clothes_v1, is_stack=True)
bar.add("商家B", CLOTHES, clothes_v2,label_color = ['green'])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <p style="color:red">bar_extra_html_text_label</p><div id="048c29661001402cbde3bc1632ace085" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_048c29661001402cbde3bc1632ace085 = echarts.init(document.getElementById('048c29661001402cbde3bc1632ace085'), 'light', {renderer: 'canvas'});
#
# var option_048c29661001402cbde3bc1632ace085 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ## 控制 X/Y 轴坐标轴线颜色以及宽度

# %%
from pyecharts import Bar
CLOTHES = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
clothes_v1 = [5, 20, 36, 10, 75, 90]
clothes_v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图")
bar.add(
    "商家A",
    CLOTHES,
    clothes_v1,
    xaxis_line_color="green",
    xaxis_line_width=5,
    xaxis_label_textcolor="black",
)
bar

# %%
import numpy as np
 
from pyecharts import Bar3D
import random
data = [(i, j, random.randint(0, 12)) for i in range(6) for j in range(6)]
#print(data)
x_name = np.arange(6)
y_name = np.arange(6)
vaule = [[d[1], d[0], d[2]] for d in data]
#print(vaule)
c = Bar3D()
c.add("",x_name,y_name,vaule,is_visualmap=True, visual_range=[0,12])
       
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'echartsgl': '/nbextensions/echarts/echarts-gl.min'
#         }
#     });
# </script>
#     <div id="9f0fa985f02645a2ba1e76782070cdd3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl'], function(echarts) {
#
# var myChart_9f0fa985f02645a2ba1e76782070cdd3 = echarts.init(document.getElementById('9f0fa985f02645a2ba1e76782070cdd3'), 'light', {renderer: 'canvas'});
#
# var option_9f0fa985f02645a2ba1e76782070cdd3 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...
